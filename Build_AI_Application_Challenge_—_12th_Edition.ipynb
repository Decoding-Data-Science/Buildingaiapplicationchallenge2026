# %% [markdown]
# <a href="https://colab.research.google.com/github/Decoding-Data-Science/Buildingaiapplicationchallenge2026/blob/main/Build_AI_Application_Challenge_%E2%80%94_12th_Edition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (Part A) Build AI Application Challenge — 12th Edition
# ## Source of Truth (working reference)
#
# _Last updated: 19 June 2026. Single place for the rules, dates, links, and points. Detailed day-by-day instructions are written separately, after the Day 2 Progress Workbook is released._
#
# ---
#
# ## 1. At a glance
#
# | | |
# |---|---|
# | **Challenge runs** | Day 0 = Sat 20 Jun → Day 8 = Sun 28 Jun 2026 |
# | **Final submission deadline** | Sunday 28 June, 11:45 PM GST (Dubai) |
# | **Live demo** | Thursday 2 July |
# | **Winner announcement** | To be confirmed |
# | **Fee** | Free to join (limited time) |
# | **Paths** | Two — pick one on Day 1 |
# | **Registration / Day 0 / checkpoints** | https://nas.com/artificialintelligence/challenges/building-ai-application-jun |
# | **Mandatory community (judges review here)** | DDS Academy Community — https://academy.decodingdatascience.com |
# | **Main communication** | WhatsApp group — https://chat.whatsapp.com/Cn2MI1qZsKsGMCJAIOBzDT |
# | **Public landing page** | https://decodingdatascience.com/ai-application-challenge/ |
# | **Participants so far** | 240+ registered |
#
# ---
#
# ## 2. The two paths (choose one on Day 1)
#
# 1. **Coding / LLM-API Path** — build by integrating LLMs and APIs (OpenAI, Bedrock, Hugging Face, etc.) into your own app.
# 2. **No-Code / Low-Code Path** — build with tools like n8n, Flowise, Make, Bubble, Gradio — no heavy coding required.
#
# > The old "Model Building Path" has been removed everywhere. There are only these two.
#
# ---
#
# ## 3. Mandatory vs Optional — the clear answer
#
# Three tiers, not one.
#
# ### ✅ Required — to be eligible and judged
# - **Register on the challenge platform** — https://nas.com/artificialintelligence/challenges/building-ai-application-jun
# - **Join the DDS Academy Community** — https://academy.decodingdatascience.com — submissions/progress are visible to judges here.
# - **Join the WhatsApp group** and introduce yourself — https://chat.whatsapp.com/Cn2MI1qZsKsGMCJAIOBzDT — main communication channel.
# - **Submit the daily checkpoints** on the platform (see calendar in Section 5).
# - Make the **final submission** by Sun 28 Jun, 11:45 PM GST.
#
# ### 🔓 Required only to unlock the free Support Kit
# - **Complete Day 0 in full** (see Section 4).
# - Then **message on WhatsApp** to request the **100% coupon** for the Build AI Support Kit (worth $39) + recordings.
# - Limited to the **first 100 people** — first come, first served.
#
# ### ➕ Optional — recommended, earns public leaderboard points
# - Social posts (LinkedIn, X, Instagram) — recommended, especially if you want a higher leaderboard rank.
# - Community engagement (comments, helping others, sharing progress).
# - Attending live sessions / the community meetup.
# - Skool community — optional.
#
# ---
#
# ## 4. Day 0 — what "complete" means (Sat 20 Jun)
#
# Taken directly from the Day 0 email. Completing all of this = Day 0 done = Support Kit unlocked.
#
# 1. **Finalize your AI application idea**
# 2. **Submit your idea through the Day 0 flow** on the challenge platform
# 3. **Join the official WhatsApp group** for live updates
# 4. **Unlock the AI App Builder Challenge Support Kit** (message on WhatsApp for the 100% coupon — first 100)
# 5. **Come prepared for the kickoff** tomorrow
#
# > Posting on LinkedIn that you're joining is **encouraged (bonus points)** — not required for Day 0. People without LinkedIn can still complete Day 0 and unlock the Support Kit.
#
# ---
#
# ## 5. Submission calendar
#
# | Day | Date | Submission type | Notes |
# |---|---|---|---|
# | Day 0 | Sat 20 Jun | Setup (idea submission via Day 0 flow) | Idea + Day 0 checklist |
# | Day 1 | Sun 21 Jun | **File submission** | Choose path + project idea |
# | Day 2 | Mon 22 Jun | **File submission** | Progress Workbook released today |
# | Day 3 | Tue 23 Jun | **File submission** | Progress report / screenshot |
# | Day 4 | Wed 24 Jun | **Share only — no file** | Share progress on LinkedIn + website |
# | Day 5 | Thu 25 Jun | **File submission** | UI / interface |
# | Day 6 | Fri 26 Jun | **File submission** | Enhancements / debugging |
# | Day 7 | Sat 27 Jun | **File submission** | Explainer video |
# | Day 8 | Sun 28 Jun | **Final submission** | Demo link + video + GitHub + LinkedIn post — by 11:45 PM GST |
#
# > Only **Day 4** is a "no file" day — share progress instead. Every other day has a real submission on the platform. Per-day task detail comes in the day-by-day rewrite.
#
# ---
#
# ## 6. Points & leaderboard
#
# Two separate systems — only one is shown to participants.
#
# ### A) Public leaderboard (shown)
# Drives the visible ranking and counts toward final judging. Built from three things: **submissions + social/community + submission timing.**
#
# **Proposed values — approve or adjust:**
#
# | Action | Points | Cap |
# |---|---|---|
# | Daily checkpoint submitted on time (file days) | +100 | per file day |
# | Day 0 completed in full | +150 | once |
# | Final submission (Day 8) on time | +200 | once |
# | Early-submission bonus (well before deadline) | +25 | per submission day |
# | LinkedIn post (join / progress / demo) | +150 | once per post type (max 3) |
# | X / Twitter post (tagged) | +50 | once |
# | Instagram post (tagged) | +50 | once |
# | Community contribution (helpful post/comment in DDS community) | +25 | capped per day |
#
# **Cap rule:** once per platform per post type, to keep it fair.
#
# ### B) Internal judging points (not shown)
# Used by judges to decide top participants. **Not visible** on the leaderboard. Based on the rubric below.
#
# | Criteria | Weight |
# |---|---|
# | Innovation | 25% |
# | Technical execution | 25% |
# | Real-world applicability | 15% |
# | Presentation (demo + LinkedIn post) | 15% |
# | Public leaderboard (Section 6A) | 20% |
#
# ---
#
# ## 7. Channels — one home base, the rest clearly secondary
#
# **Core (required):**
# - Challenge platform (register / Day 0 / checkpoints) — https://nas.com/artificialintelligence/challenges/building-ai-application-jun
# - DDS Academy Community (submissions visible to judges) — https://academy.decodingdatascience.com
# - WhatsApp group (communication) — https://chat.whatsapp.com/Cn2MI1qZsKsGMCJAIOBzDT
#
# **Share / optional (bonus points):**
# - LinkedIn group — https://www.linkedin.com/groups/9371112/
# - LinkedIn company page — https://www.linkedin.com/company/decodingdatascience/
# - DDS Business Circle (tag) — https://www.linkedin.com/company/dds-business-circle/
# - Instagram — https://www.instagram.com/decodingdatascience/
# - X — https://x.com/decodingdatasci
# - YouTube playlist — https://youtube.com/playlist?list=PLkT-YdCzItPEmSuh4V3K_YkyuqSxJUT0l
# - Skool — https://skool.com/decoding-data-science-6929/
# - All socials (Linktree) — https://linktr.ee/decodingdatascience
# - Founder (Mohammad Arshad) — https://www.linkedin.com/in/mdarshad/
#
# > Rule going forward: each public-facing message points to the **one** action that matters for that step — not all links at once.
#
# ---
#
# ## 8. Rewards (summary)
#
# Headline prizes: AI Residency Cohort seat, AI for Builders, CAIO, finalist scholarships, JetBrains licenses (5), Google cloud credits, top-10 interview opportunity, swag — roughly $6,900 in scholarships, plus a CPD certificate.
#
# **Standard eligibility line (use on all reward mentions):**
# _Scholarships, licenses, swag, and opportunities are subject to eligibility, project quality, final review, and partner terms._

# %% [markdown]
# # (Part B) Build AI Application Challenge — 12th Edition
# ## Daily Instructions: Day 1 – Day 3
#
# _Each day below is self-contained — copy/post one day at a time. Two paths are split clearly. There is one required submission per day, with bonus actions separated. `[link]` = drop your real link in._
#
# **Where things go (same every day):**
# - **Submit checkpoints on the challenge platform:** https://nas.com/artificialintelligence/challenges/building-ai-application-jun
# - **Post progress in the DDS Academy Community (judges review here):** https://academy.decodingdatascience.com
# - **Live updates / questions:** WhatsApp group — https://chat.whatsapp.com/Cn2MI1qZsKsGMCJAIOBzDT
#
# ---
#
# # Day 1 — Kickoff & Project Ideation
# **Sun 21 Jun · Required: file submission**
#
# **Goal:** Lock your idea, choose your path, and submit your project proposal.
#
# **Watch first:** `[Day 1 kickoff video]`
#
# ### Your tasks today
#
# **Everyone:**
# 1. **Choose ONE path** and commit to it for the whole challenge:
#    - **Coding / LLM-API Path** — build by integrating LLMs/APIs into your own app.
#    - **No-Code / Low-Code Path** — build with tools like n8n, Flowise, Make, Bubble, or Gradio.
# 2. **Define your AI application clearly:**
#    - The problem it solves
#    - Who it's for (target user)
#    - What it does (core feature, in one sentence)
#    - Why AI is needed
# 3. **Make your own copy** of the Project Proposal template `[template link]` (File → Make a copy — do **not** request edit access; it's shared with the whole community).
# 4. Fill in the **Day 1 section**: idea, chosen path, target user, planned tools/stack.
#
# **Coding / LLM-API path — start setup:**
# - Create a **GitHub repo** for your project.
# - Decide your model/API (OpenAI, Gemini, Bedrock, Hugging Face) — see the model-selection guides below.
#
# **No-Code / Low-Code path — start setup:**
# - Pick your main tool and create your account/workspace.
# - Sketch your workflow: **input → AI step → output**.
#
# ### Today's submission (required)
# Submit your completed **Project Proposal (Day 1 section)** on the challenge platform — Google Doc link or PDF.
#
# ### Optional — earns bonus points
# - Post on LinkedIn that you've joined and what you're building; tag Decoding Data Science. **(+150, once)**
#
# ### Helpful resources
# - Choosing an OpenAI model: https://decodingdatascience.com/how-to-choose-the-right-openai-model-gpt-5-complete-guide/
# - Choosing a Gemini model: https://decodingdatascience.com/choosing-the-right-gemini-model-for-your-ai-project-a-beginner-friendly-guide/
# - GitHub for beginners: https://youtu.be/bV_9mr5O5bg
# - Get an OpenAI API key: https://www.youtube.com/watch?v=CVnTzj-qhCU
#
# ---
#
# # Day 2 — Environment Setup & First Build
# **Mon 22 Jun · Required: file submission**
#
# **Goal:** Get your tools working and make your first real progress. **The Progress Workbook (Days 2–8) is released today.**
#
# **Watch first:** `[Day 2 video]`
#
# ### Your tasks today
#
# **Everyone:**
# 1. **Download your own copy of the Progress Workbook (Days 2–8)** `[workbook link]` — make a local copy, do **not** request edit access.
# 2. Use this **one** workbook for the rest of the challenge — add a new section each day.
#
# **Coding / LLM-API path:**
# - Set up your environment (Python + the libraries/SDKs for your chosen API).
# - Get your **API key working** and test a basic call — confirm you can send a request and get a response back.
# - Commit your initial setup to **GitHub**.
#
# **No-Code / Low-Code path:**
# - Set up your tool and connect any needed accounts/APIs.
# - Build a **simple working prototype** — even just one input → AI step → output.
#
# ### Today's submission (required)
# Update the **Day 2 section** of your Progress Workbook (setup done, first build started) and submit it on the platform.
# - Coding path: include your **GitHub repo link**.
#
# ### Optional — earns bonus points
# - Share your progress in the LinkedIn group `https://www.linkedin.com/groups/9371112/`
# - Tweet your experience — tag **@decodingdatasci**, use **#decodingdatascience** **(+50)**
#
# ### Helpful resources
# - Python environment setup: https://www.youtube.com/watch?v=D5XyQ96EgiM
# - GitHub: https://youtu.be/bV_9mr5O5bg
# - OpenAI API key: https://www.youtube.com/watch?v=CVnTzj-qhCU
#
# ---
#
# # Day 3 — Core Functionality
# **Tue 23 Jun · Required: file submission**
#
# **Goal:** Make your app actually do its main job — strengthen the core of your application.
#
# **Watch first:** `[Day 3 video]`
#
# ### Your tasks today
#
# **Coding / LLM-API path:**
# - Expand your API integration: handle real inputs, multi-step or multi-turn logic, and context.
# - Add **error handling** (timeouts, rate limits, invalid responses).
# - If using an LLM, start **refining your prompts** for clearer, more consistent output.
# - Begin wiring the logic into a basic interface if you can.
#
# **No-Code / Low-Code path:**
# - Build out your **core workflow**: connect the steps, wire in your AI/API, automate the key actions.
# - Test the **full flow end-to-end** and fix any logic gaps.
# - Make the interface clear and usable.
#
# ### Today's submission (required)
# Add a short **1-page progress report** to your Progress Workbook covering: what's working, what you built/integrated today, challenges faced, and current status. Submit on the platform.
# - A **screenshot/image** of your app or code is enough as proof for today.
# - Coding path: **push your latest code to GitHub**.
#
# ### Optional — earns bonus points
# - Share a progress post in the LinkedIn group `https://www.linkedin.com/groups/9371112/` (tag DDS)
# - Post on Instagram / X about your build **(+50 each, once per platform)**
#
# ### Helpful resources
# - GitHub getting started: https://www.youtube.com/watch?v=857AyFXH6OY
# - Picking a model for the task: https://decodingdatascience.com/openai-guide-to-use-which-model-for-tasks/
